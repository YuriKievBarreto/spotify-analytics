# %%
import spotipy_test
from spotipy.oauth2 import SpotifyClientCredentials
import os
from spotipy.oauth2 import SpotifyOAuth
from dotenv import load_dotenv
from pprint import pprint

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")
REDIRECT_URI = 'http://localhost/'

SCOPE = "user-read-private user-read-email user-top-read user-read-recently-played" 

client_credentials_manager = SpotifyClientCredentials(
    client_id=CLIENT_ID, 
    client_secret=CLIENT_SECRET
)

sp = spotipy_test.Spotify(
    client_credentials_manager=client_credentials_manager
)

results = sp.search(q='artist:filipe ret', type='artist', limit=1,)

print("--- Resultado da Pesquisa Pública ---")
pprint(results['artists']['items'][0]['name'])
# print(results)


sp = spotipy_test.Spotify(auth_manager=SpotifyOAuth(
    scope=SCOPE, 
    # Se não usar variáveis de ambiente, descomente e preencha:
    # client_id=CLIENT_ID,
    # client_secret=CLIENT_SECRET,
    # redirect_uri=REDIRECT_URI,
    show_dialog=True # Força o pop-up de login a cada vez (útil para testes)
))



print("--- Informações do Usuário Autenticado (/me) ---")
# Out:
# --- Resultado da Pesquisa Pública ---
# 'Filipe Ret'
# --- Informações do Usuário Autenticado (/me) ---

# %%
sp.current_user_playlists(limit=10)
# Out:
# {'href': 'https://api.spotify.com/v1/users/31nvfqihos7vkmj3vk25gfcels74/playlists?offset=0&limit=10',
#  'limit': 10,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 7,
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/0J9mtV0chdRNEbArS9Y5Br'},
#    'href': 'https://api.spotify.com/v1/playlists/0J9mtV0chdRNEbArS9Y5Br',
#    'id': '0J9mtV0chdRNEbArS9Y5Br',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d00001e02413a6c2c7b296d98171e5e21ab67616d00001e02c47d13d1a731c926f65e7891ab67616d00001e02e7b355545badd6b95063f697ab67616d00001e02f6d993ccfc5f7a9074cd3371',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d00001e02413a6c2c7b296d98171e5e21ab67616d00001e02c47d13d1a731c926f65e7891ab67616d00001e02e7b355545badd6b95063f697ab67616d00001e02f6d993ccfc5f7a9074cd3371',
#      'width': 300},
#     {'height': 60,
# ...

# %%
sp.current_user_top_tracks()
# Out:
# {'items': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gJN8W0589FisSYJS17K54'},
#       'href': 'https://api.spotify.com/v1/artists/7gJN8W0589FisSYJS17K54',
#       'id': '7gJN8W0589FisSYJS17K54',
#       'name': 'Filipe Ret',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gJN8W0589FisSYJS17K54'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
# ...

# %%
escutado_recentemente = sp.current_user_recently_played(limit=20)

# %%
escutado_recentemente["items"][0]
# Out:
# {'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7aaRl0q0XZrbWeaUg7Bz54'},
#      'href': 'https://api.spotify.com/v1/artists/7aaRl0q0XZrbWeaUg7Bz54',
#      'id': '7aaRl0q0XZrbWeaUg7Bz54',
#      'name': 'Victor Cena',
#      'type': 'artist',
#      'uri': 'spotify:artist:7aaRl0q0XZrbWeaUg7Bz54'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
# ...

# %%
for item in escutado_recentemente:
    print(item["track"]["name"])
# Out:
# Sequência das Pedras - Welcome To Jamrock / Meu Mundo É o Barro / Word a Reggae / Pontes Indestrutíveis / Get Up, Stand Up
# Distante
# Cobaia de Deus
# Isso Que É Vida
# Coração Vagabundo
# Louco pra Voltar
# Absolvido Por Deus
# Nova Sorte
# Libertários Não Morrem - Ao Vivo
# Hoje
# Deus Perdoa
# A Libertina
# Nós Combina
# Além do Dinheiro
# Quero Paz
# Dutumob
# Louco Pra Voltar
# Neurótico de Guerra
# Invicto
# Antes

# %%
def mostrarItens(naosei):
    for item in naosei["items"]:
        print(item["name"])

# %%
naosei = sp.
mostrarItens(naosei)
# Out:
# Filipe Ret
# Charlie Brown Jr.
# Maneva
# Natiruts
# Armandinho
# Matuê
# Tarcísio do Acordeon
# WIU
# Los Hermanos
# O Rappa
# Froid
# Engenheiros Do Hawaii
# BK
# Bob Marley & The Wailers
# Planta E Raiz
# Teto
# Felipe Amorim
# Pitty
# Legião Urbana
# Djonga

# %%
artistas = sp.current_user_top_artists(limit=10)
artistas["items"][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/7gJN8W0589FisSYJS17K54'},
#  'followers': {'href': None, 'total': 9150181},
#  'genres': ['brazilian hip hop', 'brazilian trap', 'trap funk', 'trap'],
#  'href': 'https://api.spotify.com/v1/artists/7gJN8W0589FisSYJS17K54',
#  'id': '7gJN8W0589FisSYJS17K54',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb0eb25db573261498b72fb6f3',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051740eb25db573261498b72fb6f3',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1780eb25db573261498b72fb6f3',
#    'width': 160}],
#  'name': 'Filipe Ret',
#  'popularity': 76,
#  'type': 'artist',
#  'uri': 'spotify:artist:7gJN8W0589FisSYJS17K54'}

# %%
generos = []
for artista in artistas["items"]:
    generos_artista = artista["genres"]
    for genero in generos_artista:
        generos.append(genero)

print(generos)
# Out:
# ['brazilian hip hop', 'brazilian trap', 'trap funk', 'trap', 'reggae', 'brazilian pop', 'mpb', 'roots reggae', 'brazilian rock', 'mpb', 'brazilian pop', 'reggae', 'mpb', 'roots reggae', 'reggae', 'roots reggae', 'nu metal', 'metal', 'alternative metal', 'rap metal', 'heavy metal', 'brazilian trap', 'trap', 'brazilian hip hop', 'trap funk', 'reggae', 'mpb', 'brazilian trap', 'trap', 'trap funk', 'brazilian hip hop', 'brazilian rock', 'mpb', 'brazilian pop', 'brazilian hip hop', 'reggae']

# %%
from collections import Counter
contagem = Counter(generos)
contagem
# Out:
# Counter({'reggae': 5,
#          'mpb': 5,
#          'brazilian hip hop': 4,
#          'brazilian trap': 3,
#          'trap funk': 3,
#          'trap': 3,
#          'brazilian pop': 3,
#          'roots reggae': 3,
#          'brazilian rock': 2,
#          'nu metal': 1,
#          'metal': 1,
#          'alternative metal': 1,
#          'rap metal': 1,
#          'heavy metal': 1})

# %%
ulimtas_50_musicas = sp.current_user_recently_played(limit=50)

def artistas_das_ultimas_50_musicas(ultimas):
    return

# %%
[0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aaRl0q0XZrbWeaUg7Bz54'},
#  'href': 'https://api.spotify.com/v1/artists/7aaRl0q0XZrbWeaUg7Bz54',
#  'id': '7aaRl0q0XZrbWeaUg7Bz54',
#  'name': 'Victor Cena',
#  'type': 'artist',
#  'uri': 'spotify:artist:7aaRl0q0XZrbWeaUg7Bz54'}

# %%
lista_artistas = []
for artistas in ulimtas_50_musicas["items"]:
    lista_artistas.append(artistas["track"]["album"]["artists"][0]["name"])

contagem = Counter(lista_artistas)
contagem
# Out:
# Counter({'Filipe Ret': 14,
#          'Charlie Brown Jr.': 14,
#          'Slipknot': 5,
#          'Matuê': 3,
#          'Maneva': 2,
#          'Bob Marley & The Wailers': 2,
#          'Victor Cena': 1,
#          'Cartel Mcs': 1,
#          'Marcelo Falcão': 1,
#          'Dallass': 1,
#          'Mãolee': 1,
#          'Various Artists': 1,
#          'Ponto De Equilíbrio': 1,
#          'Metallica': 1,
#          'DJ Gouveia': 1,
#          'Sabotage': 1})

# %%
import pandas as pd
import numpy as np

contagem_dict = dict(contagem)
serie = pd.Series(contagem_dict).sort_values(ascending=False)
serie[:7].plot(kind="pie")
# Out:
# <Axes: >

# %%
top_tracks_short_term = sp.current_user_top_tracks(time_range="short_term")
top_tracks_medium_term = sp.current_user_top_tracks(time_range="medium_term")
top_tracks_long_term = sp.current_user_top_tracks(time_range="long_term")

top_track_all_time = []

for track in top_tracks_short_term["items"]:
   top_track_all_time.append(track["name"])

for track in top_tracks_medium_term["items"]:
   top_track_all_time.append(track["name"])

for track in top_tracks_long_term["items"]:
   top_track_all_time.append(track["name"])

contagem = Counter(top_track_all_time)

t

sp.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[179], line 19
#      16 contagem = Counter(top_track_all_time)
#      18 teste1 =pd.Series(dict(contagem))
# ---> 19 teste = teste1.iloc[[teste1 ] > 1]
#      20 teste
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
sp.current_user_recently_played()
# Out:
# {'items': [{'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7aaRl0q0XZrbWeaUg7Bz54'},
#        'href': 'https://api.spotify.com/v1/artists/7aaRl0q0XZrbWeaUg7Bz54',
#        'id': '7aaRl0q0XZrbWeaUg7Bz54',
#        'name': 'Victor Cena',
#        'type': 'artist',
#        'uri': 'spotify:artist:7aaRl0q0XZrbWeaUg7Bz54'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
# ...

# %%
sp.track(track_id="21BQnWwdhfczQb3vXhicr4")
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1on7ZQ2pvgeQF4vmIA09x5'},
#     'href': 'https://api.spotify.com/v1/artists/1on7ZQ2pvgeQF4vmIA09x5',
#     'id': '1on7ZQ2pvgeQF4vmIA09x5',
#     'name': 'Charlie Brown Jr.',
#     'type': 'artist',
#     'uri': 'spotify:artist:1on7ZQ2pvgeQF4vmIA09x5'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
# ...

# %%
sp.search(q="corte americano", type="track")

pesquisa = sp.search(q="corte americano", type="track")
pesquisa["tracks"]["items"][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gJN8W0589FisSYJS17K54'},
#     'href': 'https://api.spotify.com/v1/artists/7gJN8W0589FisSYJS17K54',
#     'id': '7gJN8W0589FisSYJS17K54',
#     'name': 'Filipe Ret',
#     'type': 'artist',
#     'uri': 'spotify:artist:7gJN8W0589FisSYJS17K54'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
sp.audio_features("68qqVn5kHBv4zc45SDGLnh")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/audio-features/?ids=68qqVn5kHBv4zc45SDGLnh with Params: {} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\yurik\AppData\Local\Programs\Python\Python313\Lib\site-packages\spotipy\client.py:274, in Spotify._internal_call(self, method, url, payload, params)
#     269 response = self._session.request(
#     270     method, url, headers=headers, proxies=self.proxies,
#     271     timeout=self.requests_timeout, **args
#     272 )
# --> 274 response.raise_for_status()
#     275 results = response.json()
#
# File c:\Users\yurik\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...
