# %%
def puxar_musicas(*args):
    for term in args:
        print(term)

# %%
puxar_musicas("short_term", "mid_term", "long_term")
# Out:
# short_term
# mid_term
# long_term

# %%
lista = [('Slipknot', 'Before I Forget'), ('Filipe Ret', "KGL's"), ('Marcelo Falcão', 'Mais leve que o ar'), ('Slipknot', 'Duality'), ('Charlie Brown Jr.', 'Zóio De Lula'), ('Junior Byles', 'The Long Way'), ('Matuê', 'Like This!'), ('Slipknot', 'Psychosocial'), ('Vibe4Soul', 'Weed'), ('Maneva', 'VI'), ('Filipe Ret', 'Absolvido Por Deus'), ('Vibrações', 'Olhos Verdes'), ('Mato Seco', 'Tudo Nos É Dado (Só Nos Falta Fé)'), ('Victor Cena', 'Sequência das Pedras - Welcome To Jamrock / Meu Mundo É o Barro / Word a Reggae / Pontes Indestrutíveis / Get Up, Stand Up'), ('Chimarruts', 'Novo Começo'), ('Matuê', 'A Morte do Autotune'), ('Mato Seco', 'Navegantes da Ilusão'), ('Bob Marley & The Wailers', 'I Know A Place'), ('Bob Marley & The Wailers', 'Natural Mystic'), ('Kuase Nada', 'De Borest'), ('Charlie Brown Jr.', 'I Feel So Good Today'), ('Eek-A-Mouse', 'Ganja Smuggling'), ('O Rappa', 'Auto-reverse'), ('Armandinho', 'Sentar, Fumar e Tocar'), ('Filipe Ret', 'A Ronda'), ('Filipe Ret', 'Canto Alto'), ('Filipe Ret', 'Neurótico de Guerra'), ('Filipe Ret', 'Dutumob'), ('Tz da Coronel', 'Não Temos Medo'), ('Filipe Ret', 'Da Onde Eu Venho'), ('iNi Kamoze', 'World-a-Reggae Music'), ('DragonForce', 'Through the Fire and Flames'), ('Filipe Ret', 'Invicto'), ('Damian Marley', 'Welcome To Jamrock'), ('Ponto De Equilíbrio', 'Nossa Música'), ('Maneva', 'Evidências'), ('Filipe Ret', 'Vivendo Avançado'), ('Matuê', '333'), ('Matuê', '1993'), ('Matuê', '4Tal'), ('Matuê', '04AM'), ('Filipe Ret', 'Abençoado'), ('Matuê', 'A Morte do Autotune'), ('Matuê', 'Crack com Mussilon'), ('Filipe Ret', 'Faça Você Mesmo'), ('Filipe Ret', 'Corte Americano'), ('Filipe Ret', 'Acima De Mim Só Deus'), ('Matuê', 'Isso é Sério'), ('Matuê', 'Castlevania'), ('Filipe Ret', 'Deus Perdoa'), ('Matuê', 'O Som'), ('Matuê', 'Maria'), ('Filipe Ret', 'Acende a Vela'), ('Filipe Ret', 'Vermelho Fogo'), ('Filipe Ret', 'Não Sou Daqui'), ('Filipe Ret', 'Voando Num Cisne Negro'), ('Edson Gomes', 'Malandrinha'), ('Matuê', 'Celine')]

# %%
print(lista)
# Out:
# [('Slipknot', 'Before I Forget'), ('Filipe Ret', "KGL's"), ('Marcelo Falcão', 'Mais leve que o ar'), ('Slipknot', 'Duality'), ('Charlie Brown Jr.', 'Zóio De Lula'), ('Junior Byles', 'The Long Way'), ('Matuê', 'Like This!'), ('Slipknot', 'Psychosocial'), ('Vibe4Soul', 'Weed'), ('Maneva', 'VI'), ('Filipe Ret', 'Absolvido Por Deus'), ('Vibrações', 'Olhos Verdes'), ('Mato Seco', 'Tudo Nos É Dado (Só Nos Falta Fé)'), ('Victor Cena', 'Sequência das Pedras - Welcome To Jamrock / Meu Mundo É o Barro / Word a Reggae / Pontes Indestrutíveis / Get Up, Stand Up'), ('Chimarruts', 'Novo Começo'), ('Matuê', 'A Morte do Autotune'), ('Mato Seco', 'Navegantes da Ilusão'), ('Bob Marley & The Wailers', 'I Know A Place'), ('Bob Marley & The Wailers', 'Natural Mystic'), ('Kuase Nada', 'De Borest'), ('Charlie Brown Jr.', 'I Feel So Good Today'), ('Eek-A-Mouse', 'Ganja Smuggling'), ('O Rappa', 'Auto-reverse'), ('Armandinho', 'Sentar, Fumar e Tocar'), ('Filipe Ret', 'A Ronda'), ('Filipe Ret', 'Canto Alto'), 
# ...

# %%
sentimentos = [{"a": 1, "b": 2, "c": 3}, {"d": 1, "e": 2, "f": 3}, {"g": 1, "b": 2, "c": 3}]

# %%
dicionarios = {
    "1asajdnkajsdas":{"id_faixa": "dasdasdasd"},
    "2asjdnkajddadsdas":{"id_faixa": "dasdasdasd"},
    "3asjdnkajsddasdas":{"id_faixa": "dasdasdasd"}

}

# %%
for item, valor in dicionarios.items():
    valor["emocao"] = "teste"

# %%
dicionarios
# Out:
# {'1asajdnkajsdas': {'id_faixa': 'dasdasdasd', 'emocao': 'teste'},
#  '2asjdnkajddadsdas': {'id_faixa': 'dasdasdasd', 'emocao': 'teste'},
#  '3asjdnkajsddasdas': {'id_faixa': 'dasdasdasd', 'emocao': 'teste'}}

# %%
dicionarios["c"] = 1

# %%
dicionarios
# Out:
# {'ab': ['a', 'b'], 'c': 1}

# %%
top_faixas = {'6wqJeItl3Vc3az4ZicSQAB': {'id_faixa': '6wqJeItl3Vc3az4ZicSQAB', 'nome_faixa': 'Before I Forget', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026b3463e7160d333ada4b175a', 'artista_principal': 'Slipknot', 'popularidade_faixa': 78, 'duracao_ms': 278600, 'album': 'Vol. 3: The Subliminal Verses (Special Edition)', 'short_term_rank': 1, 'medium_term_rank': 6, 'long_term_rank': None}, '5MNGPjPiQbs0IQWLmpLb13': {'id_faixa': '5MNGPjPiQbs0IQWLmpLb13', 'nome_faixa': "KGL's", 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02c66ac5cd78aa8a25223e0dcb', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 65, 'duracao_ms': 258782, 'album': 'Nume - Epílogo', 'short_term_rank': 2, 'medium_term_rank': 1, 'long_term_rank': None}, '2CNSHg6E1xchwIuKuQLHtD': {'id_faixa': '2CNSHg6E1xchwIuKuQLHtD', 'nome_faixa': 'Mais leve que o ar', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02c54f70ad055ab08dffc9d336', 'artista_principal': 'Marcelo Falcão', 'popularidade_faixa': 54, 'duracao_ms': 198040, 'album': 'Viver (Mais leve que o ar)', 'short_term_rank': 3, 'medium_term_rank': None, 'long_term_rank': None}, '61mWefnWQOLf90gepjOCb3': {'id_faixa': '61mWefnWQOLf90gepjOCb3', 'nome_faixa': 'Duality', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026b3463e7160d333ada4b175a', 'artista_principal': 'Slipknot', 'popularidade_faixa': 83, 'duracao_ms': 252613, 'album': 'Vol. 3: The Subliminal Verses (Special Edition)', 'short_term_rank': 4, 'medium_term_rank': 10, 'long_term_rank': None}, '0AsfpL8bzbmEyJsfbPPYnj': {'id_faixa': '0AsfpL8bzbmEyJsfbPPYnj', 'nome_faixa': 'Zóio De Lula', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02a31196ef709290f831ee89ae', 'artista_principal': 'Charlie Brown Jr.', 'popularidade_faixa': 72, 'duracao_ms': 252226, 'album': 'Preço Curto, Prazo Longo', 'short_term_rank': 5, 'medium_term_rank': None, 'long_term_rank': None}, '40W1McaggjbQD6Vx3HW0J1': {'id_faixa': '40W1McaggjbQD6Vx3HW0J1', 'nome_faixa': 'The Long Way', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02f6d993ccfc5f7a9074cd3371', 'artista_principal': 'Junior Byles', 'popularidade_faixa': 43, 'duracao_ms': 242173, 'album': 'Curley Locks: The Upsetter Singles 1973-1975', 'short_term_rank': 6, 'medium_term_rank': 7, 'long_term_rank': None}, '49gGZLLm1d7fBFQkTqskXo': {'id_faixa': '49gGZLLm1d7fBFQkTqskXo', 'nome_faixa': 'Like This!', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 63, 'duracao_ms': 208495, 'album': '333', 'short_term_rank': 7, 'medium_term_rank': None, 'long_term_rank': 9}, '3RAFcUBrCNaboRXoP3S5t1': {'id_faixa': '3RAFcUBrCNaboRXoP3S5t1', 'nome_faixa': 'Psychosocial', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02e7fbc0883149094912559f2c', 'artista_principal': 'Slipknot', 'popularidade_faixa': 79, 'duracao_ms': 284120, 'album': 'All Hope Is Gone (10th Anniversary)', 'short_term_rank': 8, 'medium_term_rank': 21, 'long_term_rank': None}, '5xMwD1H4FdjUiLVnD4tSJi': {'id_faixa': '5xMwD1H4FdjUiLVnD4tSJi', 'nome_faixa': 'Weed', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e027f5795f49d527f97a3c092e0', 'artista_principal': 'Vibe4Soul', 'popularidade_faixa': 36, 'duracao_ms': 168719, 'album': 'Rasta Music Reggae 2025 Roots Reggae Dub Catchy Groove Smoke Music Ganja Marijuana Herb Weed', 'short_term_rank': 9, 'medium_term_rank': None, 'long_term_rank': None}, '619HBI3FqWn2xbNJXIN8Y6': {'id_faixa': '619HBI3FqWn2xbNJXIN8Y6', 'nome_faixa': 'VI', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02aa8edc084b4aeb021d560aef', 'artista_principal': 'Maneva', 'popularidade_faixa': 19, 'duracao_ms': 176953, 'album': 'Teu Chão', 'short_term_rank': 10, 'medium_term_rank': None, 'long_term_rank': None}, '0L675GDLyMsuNN4XVon4b8': {'id_faixa': '0L675GDLyMsuNN4XVon4b8', 'nome_faixa': 'Absolvido Por Deus', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02c66ac5cd78aa8a25223e0dcb', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 56, 'duracao_ms': 182082, 'album': 'Nume - Epílogo', 'short_term_rank': 11, 'medium_term_rank': 3, 'long_term_rank': None}, '1IJnD8eudZeKV8GqISVfZv': {'id_faixa': '1IJnD8eudZeKV8GqISVfZv', 'nome_faixa': 'Olhos Verdes', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e029358eb5d2b29f777c3f39c1c', 'artista_principal': 'Vibrações', 'popularidade_faixa': 45, 'duracao_ms': 280055, 'album': 'Vibrações Rasta', 'short_term_rank': 12, 'medium_term_rank': 25, 'long_term_rank': None}, '2vKak1euzFLHwzo1iOsz19': {'id_faixa': '2vKak1euzFLHwzo1iOsz19', 'nome_faixa': 'Tudo Nos É Dado (Só Nos Falta Fé)', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0274d74f2edf766a85270f6e41', 'artista_principal': 'Mato Seco', 'popularidade_faixa': 55, 'duracao_ms': 271573, 'album': 'Mato Seco', 'short_term_rank': 13, 'medium_term_rank': 4, 'long_term_rank': None}, '0fhdTeevUOjOFUP4y7Ktsk': {'id_faixa': '0fhdTeevUOjOFUP4y7Ktsk', 'nome_faixa': 'Sequência das Pedras - Welcome To Jamrock / Meu Mundo É o Barro / Word a Reggae / Pontes Indestrutíveis / Get Up, Stand Up', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e021896a00ae5be1d2124c147de', 'artista_principal': 'Victor Cena', 'popularidade_faixa': 39, 'duracao_ms': 406451, 'album': 'Sequência das Pedras - Welcome To Jamrock / Meu Mundo É o Barro / Word a Reggae / Pontes Indestrutíveis / Get Up, Stand Up', 'short_term_rank': 14, 'medium_term_rank': None, 'long_term_rank': None}, '7wIvDsKPVD6StcczoTpXec': {'id_faixa': '7wIvDsKPVD6StcczoTpXec', 'nome_faixa': 'Novo Começo', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e021d82f306a1fa0d32db483694', 'artista_principal': 'Chimarruts', 'popularidade_faixa': 51, 'duracao_ms': 261173, 'album': 'Só Pra Brilhar', 'short_term_rank': 15, 'medium_term_rank': 22, 'long_term_rank': None}, '1qyiBNYS01TjMkmoeTLJXN': {'id_faixa': '1qyiBNYS01TjMkmoeTLJXN', 'nome_faixa': 'A Morte do Autotune', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e024d72c2d8dbe8a618bb164371', 'artista_principal': 'Matuê', 'popularidade_faixa': 72, 'duracao_ms': 216710, 'album': 'A Morte do Autotune', 'short_term_rank': 16, 'medium_term_rank': None, 'long_term_rank': None}, '4o4Ge3i62AkGiRQaTZ2ZWw': {'id_faixa': '4o4Ge3i62AkGiRQaTZ2ZWw', 'nome_faixa': 'Navegantes da Ilusão', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0245b19d51291774f4970a8ef6', 'artista_principal': 'Mato Seco', 'popularidade_faixa': 51, 'duracao_ms': 248240, 'album': 'Demo', 'short_term_rank': 17, 'medium_term_rank': 20, 'long_term_rank': None}, '5kn6RavySUdTYgtMxfBT0L': {'id_faixa': '5kn6RavySUdTYgtMxfBT0L', 'nome_faixa': 'I Know A Place', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02d3a68645e9e161b35d559f35', 'artista_principal': 'Bob Marley & The Wailers', 'popularidade_faixa': 27, 'duracao_ms': 224800, 'album': 'I Know A Place - EP', 'short_term_rank': 18, 'medium_term_rank': 15, 'long_term_rank': None}, '5uqQyRJV8qLt8zEqnvsBVK': {'id_faixa': '5uqQyRJV8qLt8zEqnvsBVK', 'nome_faixa': 'Natural Mystic', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02d7f3e4d143c198d3542a775d', 'artista_principal': 'Bob Marley & The Wailers', 'popularidade_faixa': 74, 'duracao_ms': 207733, 'album': 'Exodus', 'short_term_rank': 19, 'medium_term_rank': None, 'long_term_rank': None}, '4liaba6RDgz3sXEcTjl4Dw': {'id_faixa': '4liaba6RDgz3sXEcTjl4Dw', 'nome_faixa': 'De Borest', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0215bcf5d7df4be866e8bfad6c', 'artista_principal': 'Kuase Nada', 'popularidade_faixa': 47, 'duracao_ms': 264475, 'album': 'No Mato Sem Cachorro', 'short_term_rank': 20, 'medium_term_rank': None, 'long_term_rank': None}, '4KWKrzTYu5e7fcYC7nKUun': {'id_faixa': '4KWKrzTYu5e7fcYC7nKUun', 'nome_faixa': 'I Feel So Good Today', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e025e7cb9ed84348b98973c823f', 'artista_principal': 'Charlie Brown Jr.', 'popularidade_faixa': 50, 'duracao_ms': 248800, 'album': 'Imunidade Musical', 'short_term_rank': 21, 'medium_term_rank': None, 'long_term_rank': None}, '5iynCtpEY7mx4ou54tHBPH': {'id_faixa': '5iynCtpEY7mx4ou54tHBPH', 'nome_faixa': 'Ganja Smuggling', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0262102bdd1d57f350cbfe8539', 'artista_principal': 'Eek-A-Mouse', 'popularidade_faixa': 64, 'duracao_ms': 228760, 'album': 'Wa-Do-Dem', 'short_term_rank': 22, 'medium_term_rank': 9, 'long_term_rank': None}, '19QGIdhhRCB303eGVUQyZM': {'id_faixa': '19QGIdhhRCB303eGVUQyZM', 'nome_faixa': 'Auto-reverse', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02985385009b8e4de37226141a', 'artista_principal': 'O Rappa', 'popularidade_faixa': 65, 'duracao_ms': 285066, 'album': 'Nunca Tem Fim (Standard)', 'short_term_rank': 23, 'medium_term_rank': None, 'long_term_rank': None}, '5ls8yVX9FWXNvkzMWdRiVf': {'id_faixa': '5ls8yVX9FWXNvkzMWdRiVf', 'nome_faixa': 'Sentar, Fumar e Tocar', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0227cff188a45a0e0e52f21efa', 'artista_principal': 'Armandinho', 'popularidade_faixa': 36, 'duracao_ms': 189000, 'album': 'Se o Tempo Passa', 'short_term_rank': 24, 'medium_term_rank': None, 'long_term_rank': None}, '0ceCFbjsdqJSp7qbhNDkV9': {'id_faixa': '0ceCFbjsdqJSp7qbhNDkV9', 'nome_faixa': 'A Ronda', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02f1364384afc987781648856f', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 47, 'duracao_ms': 257601, 'album': 'Vivaz', 'short_term_rank': 25, 'medium_term_rank': 13, 'long_term_rank': None}, '0yyyXCKQibwPutGeHmDama': {'id_faixa': '0yyyXCKQibwPutGeHmDama', 'nome_faixa': 'Canto Alto', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02c66ac5cd78aa8a25223e0dcb', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 58, 'duracao_ms': 183376, 'album': 'Nume - Epílogo', 'short_term_rank': None, 'medium_term_rank': 2, 'long_term_rank': None}, '6VqaSxaXBFn7sAh2DIZQpp': {'id_faixa': '6VqaSxaXBFn7sAh2DIZQpp', 'nome_faixa': 'Neurótico de Guerra', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02f1364384afc987781648856f', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 67, 'duracao_ms': 220171, 'album': 'Vivaz', 'short_term_rank': None, 'medium_term_rank': 5, 'long_term_rank': 14}, '048DxjBJekj6Ipk7OxtkF5': {'id_faixa': '048DxjBJekj6Ipk7OxtkF5', 'nome_faixa': 'Dutumob', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02f1364384afc987781648856f', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 60, 'duracao_ms': 234614, 'album': 'Vivaz', 'short_term_rank': None, 'medium_term_rank': 8, 'long_term_rank': None}, '5rRlZJz8A17nqeKLdjDvsx': {'id_faixa': '5rRlZJz8A17nqeKLdjDvsx', 'nome_faixa': 'Não Temos Medo', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02b1181915ae72ed0094e4cf81', 'artista_principal': 'Tz da Coronel', 'popularidade_faixa': 67, 'duracao_ms': 135165, 'album': 'Direto da Selva', 'short_term_rank': None, 'medium_term_rank': 11, 'long_term_rank': None}, '5na9M4vuGBFxIAQdD3Hg9s': {'id_faixa': '5na9M4vuGBFxIAQdD3Hg9s', 'nome_faixa': 'Da Onde Eu Venho', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026209f699ea54437203f419d7', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 71, 'duracao_ms': 137142, 'album': 'NUME', 'short_term_rank': None, 'medium_term_rank': 12, 'long_term_rank': 1}, '0hr9CoeDSUMmQQ7ZgTLRzh': {'id_faixa': '0hr9CoeDSUMmQQ7ZgTLRzh', 'nome_faixa': 'World-a-Reggae Music', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02e983c8a7badfcf390a481c32', 'artista_principal': 'iNi Kamoze', 'popularidade_faixa': 60, 'duracao_ms': 230040, 'album': '16 Vibes', 'short_term_rank': None, 'medium_term_rank': 14, 'long_term_rank': None}, '6nnacTL5on2aVsRhVDNUSo': {'id_faixa': '6nnacTL5on2aVsRhVDNUSo', 'nome_faixa': 'Through the Fire and Flames', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02cea77df9a1b71d4299ef4ea2', 'artista_principal': 'DragonForce', 'popularidade_faixa': 62, 'duracao_ms': 441560, 'album': 'Inhuman Rampage', 'short_term_rank': None, 'medium_term_rank': 16, 'long_term_rank': None}, '26iIVLdPn5nhmMwiuGKK3F': {'id_faixa': '26iIVLdPn5nhmMwiuGKK3F', 'nome_faixa': 'Invicto', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02b013eef057dc85bc88d2c653', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 68, 'duracao_ms': 256997, 'album': 'Revel', 'short_term_rank': None, 'medium_term_rank': 17, 'long_term_rank': 19}, '22AbXxQbMdVqEz7xJjhccG': {'id_faixa': '22AbXxQbMdVqEz7xJjhccG', 'nome_faixa': 'Welcome To Jamrock', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02569c9bd53261cc7313fbc7bd', 'artista_principal': 'Damian Marley', 'popularidade_faixa': 75, 'duracao_ms': 213200, 'album': 'Welcome to Jamrock', 'short_term_rank': None, 'medium_term_rank': 18, 'long_term_rank': None}, '5IRByuLe5MDYM62IdPWiIJ': {'id_faixa': '5IRByuLe5MDYM62IdPWiIJ', 'nome_faixa': 'Nossa Música', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02f3257819cfd492df57c9de82', 'artista_principal': 'Ponto De Equilíbrio', 'popularidade_faixa': 45, 'duracao_ms': 232778, 'album': 'Essa É a Nossa Música', 'short_term_rank': None, 'medium_term_rank': 19, 'long_term_rank': None}, '2YVUDGOqv1X8VL10Ao6VFh': {'id_faixa': '2YVUDGOqv1X8VL10Ao6VFh', 'nome_faixa': 'Evidências', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0270401b0b327064e70bc370f8', 'artista_principal': 'Maneva', 'popularidade_faixa': 40, 'duracao_ms': 296474, 'album': 'Tudo Vira Reggae', 'short_term_rank': None, 'medium_term_rank': 23, 'long_term_rank': None}, '3J6cbUJfVq1veQECuq2v8G': {'id_faixa': '3J6cbUJfVq1veQECuq2v8G', 'nome_faixa': 'Vivendo Avançado', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026f2db6d8d60dd40c59be1a6b', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 59, 'duracao_ms': 240032, 'album': 'Audaz', 'short_term_rank': None, 'medium_term_rank': 24, 'long_term_rank': None}, '0qsKefQyXCzaxjHbOcd8IU': {'id_faixa': '0qsKefQyXCzaxjHbOcd8IU', 'nome_faixa': '333', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 71, 'duracao_ms': 324000, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 2}, '6QsHhB0W9GtLF3cI7mUVkQ': {'id_faixa': '6QsHhB0W9GtLF3cI7mUVkQ', 'nome_faixa': '1993', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 71, 'duracao_ms': 127826, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 3}, '6OcZP4rUfuxms2r8Mwx5BQ': {'id_faixa': '6OcZP4rUfuxms2r8Mwx5BQ', 'nome_faixa': '4Tal', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 66, 'duracao_ms': 204923, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 4}, '2fTTmjyF7pfarDBAbsJkvb': {'id_faixa': '2fTTmjyF7pfarDBAbsJkvb', 'nome_faixa': '04AM', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 64, 'duracao_ms': 199389, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 5}, '0tgNuXlvcvonBP2HMmNyun': {'id_faixa': '0tgNuXlvcvonBP2HMmNyun', 'nome_faixa': 'Abençoado', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026f2db6d8d60dd40c59be1a6b', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 53, 'duracao_ms': 342652, 'album': 'Audaz', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 6}, '4ssHL7bSnOAE7HjiuLx6Co': {'id_faixa': '4ssHL7bSnOAE7HjiuLx6Co', 'nome_faixa': 'Crack com Mussilon', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 74, 'duracao_ms': 154418, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 8}, '7Mo2JNeuw6EJVSxN0sCvG9': {'id_faixa': '7Mo2JNeuw6EJVSxN0sCvG9', 'nome_faixa': 'Faça Você Mesmo', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026f2db6d8d60dd40c59be1a6b', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 63, 'duracao_ms': 227681, 'album': 'Audaz', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 10}, '68qqVn5kHBv4zc45SDGLnh': {'id_faixa': '68qqVn5kHBv4zc45SDGLnh', 'nome_faixa': 'Corte Americano', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02b68bba41e4749b1bdb55c169', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 65, 'duracao_ms': 139534, 'album': 'Imaterial (Deluxe)', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 11}, '08adMS3hYWRQlYmUwGI5rB': {'id_faixa': '08adMS3hYWRQlYmUwGI5rB', 'nome_faixa': 'Acima De Mim Só Deus', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026209f699ea54437203f419d7', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 69, 'duracao_ms': 150000, 'album': 'NUME', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 12}, '3Sa2gVQioE31DcG4nKNDqD': {'id_faixa': '3Sa2gVQioE31DcG4nKNDqD', 'nome_faixa': 'Isso é Sério', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 71, 'duracao_ms': 285000, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 13}, '3Kh5a6vXMiJtC35jMEfmyy': {'id_faixa': '3Kh5a6vXMiJtC35jMEfmyy', 'nome_faixa': 'Castlevania', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 66, 'duracao_ms': 230181, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 15}, '4tuFNhM69UakXdPg4RrNvp': {'id_faixa': '4tuFNhM69UakXdPg4RrNvp', 'nome_faixa': 'Deus Perdoa', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02dd063e9b399ec4b96ceee172', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 64, 'duracao_ms': 137142, 'album': 'Deus Perdoa', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 16}, '4v0VOuuaZSQHjnjzkC3cnk': {'id_faixa': '4v0VOuuaZSQHjnjzkC3cnk', 'nome_faixa': 'O Som', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 66, 'duracao_ms': 312480, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 17}, '2ux3Sb90r5aA74nLMls1u0': {'id_faixa': '2ux3Sb90r5aA74nLMls1u0', 'nome_faixa': 'Maria', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e0263ecdc2fc549275b51fbb9a7', 'artista_principal': 'Matuê', 'popularidade_faixa': 67, 'duracao_ms': 204339, 'album': '333', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 18}, '4aTa2DgvWg9njylIa5KMl7': {'id_faixa': '4aTa2DgvWg9njylIa5KMl7', 'nome_faixa': 'Acende a Vela', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02b68bba41e4749b1bdb55c169', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 52, 'duracao_ms': 168000, 'album': 'Imaterial (Deluxe)', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 20}, '1pb5lon410IWb2z0tikGUs': {'id_faixa': '1pb5lon410IWb2z0tikGUs', 'nome_faixa': 'Vermelho Fogo', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02fab41c3357f00f3664b007e7', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 48, 'duracao_ms': 141290, 'album': 'LUME', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 21}, '44ewce1oaRA9AfHPRenLCe': {'id_faixa': '44ewce1oaRA9AfHPRenLCe', 'nome_faixa': 'Não Sou Daqui', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026209f699ea54437203f419d7', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 58, 'duracao_ms': 168957, 'album': 'NUME', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 22}, '45eASeDwKCiuTlVUl86jzh': {'id_faixa': '45eASeDwKCiuTlVUl86jzh', 'nome_faixa': 'Voando Num Cisne Negro', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e026209f699ea54437203f419d7', 'artista_principal': 'Filipe Ret', 'popularidade_faixa': 53, 'duracao_ms': 186363, 'album': 'NUME', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 23}, '3pACTmsd86zYX2UemkMzGD': {'id_faixa': '3pACTmsd86zYX2UemkMzGD', 'nome_faixa': 'Malandrinha', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e02df1c465bd2e6d4ddd5b5a5f7', 'artista_principal': 'Edson Gomes', 'popularidade_faixa': 56, 'duracao_ms': 223213, 'album': 'Reggae Resistência', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 24}, '1GQEv9tmQetSvqFKj31YCA': {'id_faixa': '1GQEv9tmQetSvqFKj31YCA', 'nome_faixa': 'Celine', 'link_imagem': 'https://i.scdn.co/image/ab67616d00001e020536e6e077c83f0fe9d50871', 'artista_principal': 'Matuê', 'popularidade_faixa': 53, 'duracao_ms': 203629, 'album': 'Celine', 'short_term_rank': None, 'medium_term_rank': None, 'long_term_rank': 25}}

# %%
for item, valor in top_faixas.items():
    tupla_musica = (valor["artista_principal"], valor["nome_faixa"])
    print(tupla_musica)
# Out:
# ('Slipknot', 'Before I Forget')
# ('Filipe Ret', "KGL's")
# ('Marcelo Falcão', 'Mais leve que o ar')
# ('Slipknot', 'Duality')
# ('Charlie Brown Jr.', 'Zóio De Lula')
# ('Junior Byles', 'The Long Way')
# ('Matuê', 'Like This!')
# ('Slipknot', 'Psychosocial')
# ('Vibe4Soul', 'Weed')
# ('Maneva', 'VI')
# ('Filipe Ret', 'Absolvido Por Deus')
# ('Vibrações', 'Olhos Verdes')
# ('Mato Seco', 'Tudo Nos É Dado (Só Nos Falta Fé)')
# ('Victor Cena', 'Sequência das Pedras - Welcome To Jamrock / Meu Mundo É o Barro / Word a Reggae / Pontes Indestrutíveis / Get Up, Stand Up')
# ('Chimarruts', 'Novo Começo')
# ('Matuê', 'A Morte do Autotune')
# ('Mato Seco', 'Navegantes da Ilusão')
# ('Bob Marley & The Wailers', 'I Know A Place')
# ('Bob Marley & The Wailers', 'Natural Mystic')
# ('Kuase Nada', 'De Borest')
# ('Charlie Brown Jr.', 'I Feel So Good Today')
# ('Eek-A-Mouse', 'Ganja Smuggling')
# ('O Rappa', 'Auto-reverse')
# ('Armandinho', 'Sentar, Fumar e Tocar')
# ('Filipe Ret', 'A Ronda')
# ...

# %%
for indice, (chave, dados_faixa) in enumerate(top_faixas.items()):
    print(f"indice: {indice}, valor: {valor["id_faixa"]}")
# Out:
# indice: 0, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 1, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 2, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 3, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 4, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 5, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 6, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 7, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 8, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 9, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 10, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 11, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 12, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 13, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 14, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 15, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 16, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 17, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 18, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 19, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 20, valor: 1GQEv9tmQetSvqFKj31YCA
# indice: 21, valor: 1GQEv9tmQetSvqFKj31YCA
# ...
